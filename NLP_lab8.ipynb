# %% [markdown]
# ## Perplexity

# %%
pip install pyplexity
# Out:
# Requirement already satisfied: pyplexity in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: Flask<3.0.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (2.2.5)
# Requirement already satisfied: cached-path<2.0.0,>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (1.6.2)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (1.1)
# Requirement already satisfied: lxml<5.0.0,>=4.7.1 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (4.9.4)
# Requirement already satisfied: memory-tempfile<3.0.0,>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (2.2.3)
# Requirement already satisfied: nltk<4.0.0,>=3.6.7 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (3.8.1)
# Requirement already satisfied: pandas<2.0.0,>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (1.5.3)
# Requirement already satisfied: storable<2.0.0,>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (1.2.4)
# Requirement already satisfied: typer[all]<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (0.4.2)
# Requirement already satisfied: warcio<2.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from pyplexity) (1.7.4)
# Requirement already satisfied: requests<3.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (2.31.0)
# Requirement already satisfied: rich<14.0,>=12.1 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (13.7.1)
# Requirement already satisfied: filelock<3.14,>=3.4 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (3.13.4)
# Requirement already satisfied: boto3<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (1.34.84)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (2.8.0)
# Requirement already satisfied: huggingface-hub<0.22.0,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from cached-path<2.0.0,>=1.0.2->pyplexity) (0.20.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3.0.0,>=2.0.2->pyplexity) (3.0.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.0.0,>=2.0.2->pyplexity) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.0.0,>=2.0.2->pyplexity) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.0.0,>=2.0.2->pyplexity) (8.1.7)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib<2.0,>=1.1->pyplexity) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib<2.0,>=1.1->pyplexity) (0.5.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.7->pyplexity) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.7->pyplexity) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.6.7->pyplexity) (4.66.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyplexity) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyplexity) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<2.0.0,>=1.1.5->pyplexity) (1.25.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from typer[all]<0.5.0,>=0.4.0->pyplexity) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<0.5.0,>=0.4.0->pyplexity) (1.5.4)
# Requirement already satisfied: botocore<1.35.0,>=1.34.84 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0,>=1.0->cached-path<2.0.0,>=1.0.2->pyplexity) (1.34.84)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0,>=1.0->cached-path<2.0.0,>=1.0.2->pyplexity) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from boto3<2.0,>=1.0->cached-path<2.0.0,>=1.0.2->pyplexity) (0.10.1)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2.11.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2.3.3)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0.0,>=1.0.2->pyplexity) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0.0,>=1.0.2->pyplexity) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0.0,>=1.0.2->pyplexity) (4.11.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<0.22.0,>=0.8.1->cached-path<2.0.0,>=1.0.2->pyplexity) (24.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->Flask<3.0.0,>=2.0.2->pyplexity) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cached-path<2.0.0,>=1.0.2->pyplexity) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cached-path<2.0.0,>=1.0.2->pyplexity) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.0->cached-path<2.0.0,>=1.0.2->pyplexity) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.1->cached-path<2.0.0,>=1.0.2->pyplexity) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0,>=12.1->cached-path<2.0.0,>=1.0.2->pyplexity) (2.16.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (3.20.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (4.9)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.10/dist-packages (from google-resumable-media>=2.3.2->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.1->cached-path<2.0.0,>=1.0.2->pyplexity) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-cloud-storage<3.0,>=1.32.0->cached-path<2.0.0,>=1.0.2->pyplexity) (0.6.0)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from pyplexity import PerplexityModel, PerplexityProcessor

model = PerplexityModel.from_str("bigrams-cord19")
text_processor = PerplexityProcessor(perpl_model=model, perpl_limit=8000.0)
clean_text = text_processor.process("This is a normal sentence. Meanwhile, hjldfuia HTML BODY this one will be deleted LINK URL COUISUDOANLHJWQKEJK")
# Out:
# Loading model... Done.

# %%
import nltk
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE
from nltk.lm import Vocabulary

train_sentences = ['an apple', 'an orange']
tokenized_text = [list(map(str.lower, nltk.tokenize.word_tokenize(sent))) for sent in train_sentences]

n = 2
train_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="</s>") for t in tokenized_text]
words = [word for sent in tokenized_text for word in sent]
words.extend(["<s>", "</s>"])
padded_vocab = Vocabulary(words)
model = MLE(n)
model.fit(train_data, padded_vocab)

test_sentences = ['an apple','an ant']
tokenized_text = [list(map(str.lower, nltk.tokenize.word_tokenize(sent))) for sent in test_sentences]

test_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="</s>") for t in tokenized_text]
for test in test_data:
    print ("MLE Estimates:", [((ngram[-1], ngram[:-1]),model.score(ngram[-1], ngram[:-1])) for ngram in test])

test_data = [nltk.bigrams(t,  pad_right=True, pad_left=True, left_pad_symbol="<s>", right_pad_symbol="</s>") for t in tokenized_text]
for i, test in enumerate(test_data):
  print("PP({0}):{1}".format(test_sentences[i], model.perplexity(test)))
# Out:
# MLE Estimates: [(('an', ('<s>',)), 1.0), (('apple', ('an',)), 0.5), (('</s>', ('apple',)), 1.0)]
# MLE Estimates: [(('an', ('<s>',)), 1.0), (('ant', ('an',)), 0.0), (('</s>', ('ant',)), 0)]
# PP(an apple):1.2599210498948732
# PP(an ant):inf

# %% [markdown]
# ## Naive Bayes

# %%
import pandas as pd
import numpy as np

data = {
    'colour': ['white', 'white', 'green', 'green', 'white', 'green', 'green', 'white'],
    'legs': [2, 3, 2, 3, 2, 3, 2, 3],
    'smell': ['yes', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no'],
    'height': ['tall', 'short', 'tall', 'short', 'tall', 'short', 'tall', 'short'],
    'species': ['mammals', 'not-mammals', 'mammals', 'not-mammals', 'mammals', 'not-mammals', 'mammals', 'not-mammals']
}

df = pd.DataFrame(data)
df
# Out:
#   colour  legs smell height      species
# 0  white     2   yes   tall      mammals
# 1  white     3    no  short  not-mammals
# 2  green     2   yes   tall      mammals
# 3  green     3    no  short  not-mammals
# 4  white     2   yes   tall      mammals
# 5  green     3    no  short  not-mammals
# 6  green     2   yes   tall      mammals
# 7  white     3    no  short  not-mammals

# %%
def calculate_frequency_table(attribute):
    freq_table = df.groupby([attribute, 'species']).size().unstack().fillna(0)
    return freq_table

calculate_frequency_table('colour')
# Out:
# species  mammals  not-mammals
# colour
# green          2            2
# white          2            2

# %%
def calculate_likelihood_table(attribute):
    freq_table = calculate_frequency_table(attribute)
    likelihood_table = freq_table.apply(lambda x: x / x.sum(), axis=1)
    return likelihood_table

calculate_likelihood_table('colour')
# Out:
# species  mammals  not-mammals
# colour
# green        0.5          0.5
# white        0.5          0.5

# %%
def predict(sample, likelihood_tables):
    predictions = {}
    for species in df['species'].unique():
        p = 1
        for attribute, value in sample.items():
            if attribute != 'species':
                p *= likelihood_tables[attribute].loc[value, species]
        predictions[species] = p
    return max(predictions, key=predictions.get)


likelihood_tables = {}
for attribute in df.columns[:-1]:
    likelihood_tables[attribute] = calculate_likelihood_table(attribute)

likelihood_tables
# Out:
# {'colour': species  mammals  not-mammals
#  colour
#  green        0.5          0.5
#  white        0.5          0.5,
#  'legs': species  mammals  not-mammals
#  legs
#  2            1.0          0.0
#  3            0.0          1.0,
#  'smell': species  mammals  not-mammals
#  smell
#  no           0.0          1.0
#  yes          1.0          0.0,
#  'height': species  mammals  not-mammals
#  height
#  short        0.0          1.0
#  tall         1.0          0.0}

# %%
sample_index = np.random.randint(0, df.shape[0])
sample = df.iloc[sample_index, :-1].to_dict()

# Predict output
prediction = predict(sample, likelihood_tables)
print("Sample:", sample)
print("Predicted species:", prediction)
# Out:
# Sample: {'colour': 'green', 'legs': 3, 'smell': 'no', 'height': 'short'}
# Predicted species: not-mammals
